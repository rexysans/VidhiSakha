# %%
import pandas as pd

# %%
df = pd.read_csv("../dataset/Constitution Of India.csv")

# %%
df.shape
# Out:
# (456, 1)

# %%
df.columns
# Out:
# Index(['Articles'], dtype='object')

# %%
df.head(10)
# Out:
#                                             Articles
# 0  1. Name and territory of the Union\n(1) India,...
# 1  1. The territories of the States; the Union te...
# 2  2. Admission or establishment of new States: P...
# 3  2A. Sikkim to be associated with the Union Rep...
# 4  3. Formation of new States and alteration of a...
# 5  4. Laws made under Articles 2 and 3 to provide...
# 6  5. Citizenship at the commencement of the Cons...
# 7  6. Rights of citizenship of certain persons wh...
# 8  7. Rights of citizenship of certain migrants t...
# 9  8. Rights of citizenship of certain persons of...

# %%
idx = pd.read_csv("../dataset/Index.csv", encoding="latin1")

# %%
idx.shape
# Out:
# (27, 3)

# %%
idx.columns
# Out:
# Index(['Parts of the Indian Constitution', 'Subject Mentioned in the Part',
#        'Articles in Indian Constitution'],
#       dtype='object')

# %%
idx.head(10)
# Out:
#   Parts of the Indian Constitution  \
# 0                           Part I
# 1                          Part II
# 2                         Part III
# 3                          Part IV
# 4                        Part IV A
# 5                           Part V
# 6                          Part VI
# 7                         Part VII
# 8                        Part VIII
# 9                          Part IX
#
#                    Subject Mentioned in the Part  \
# 0                          Union & Its Territory
# 1                                    Citizenship
# 2                             Fundamental Rights
# 3                           Directive Principles
# 4                             Fundamental Duties
# 5                                      The Union
# 6                                     The States
# 7  Note: 7th Amendment Act, 1956 repealed Part 7
# 8                          The Union Territories
# 9                                 The Panchayats
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("ltr_dataset.csv")
print(df.groupby("query")["is_correct"].sum().sort_values().head())
# Out:
# query
# reservation                    0
# Article 19 restrictions        1
# Article 356 explanation        1
# Article 21                     1
# abolition of untouchability    1
# Name: is_correct, dtype: int64
